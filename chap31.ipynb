# %%
people = 30
cars = 40
trucks = 15


if cars > people:
    print("We should take the cars.")
elif cars < people:
    print("We should not take the cars.")
else:
    print("We can't decide.")

if trucks > cars:
    print("That's too many trucks.")
elif trucks < cars:
    print("Maybe we could take the trucks.")
else:
    print("We still can't decide.")

if people > trucks:
    print("Alright, let's just take the trucks.")
else:
    print("Fine, let's stay home then.")
# Out:
# We should take the cars.
# Maybe we could take the trucks.
# Alright, let's just take the trucks.

# %%
from dis import dis

dis('''
if cars > people:
    print("We should take the cars.")
elif cars < people:
    print("We should not take the cars.")
else:
    print("We can't decide.")
''')
# Out:
#   0           RESUME                   0
#
#   2           LOAD_NAME                0 (cars)
#               LOAD_NAME                1 (people)
#               COMPARE_OP             148 (bool(>))
#               POP_JUMP_IF_FALSE        9 (to L1)
#
#   3           LOAD_NAME                2 (print)
#               PUSH_NULL
#               LOAD_CONST               0 ('We should take the cars.')
#               CALL                     1
#               POP_TOP
#               RETURN_CONST             3 (None)
#
#   4   L1:     LOAD_NAME                0 (cars)
#               LOAD_NAME                1 (people)
#               COMPARE_OP              18 (bool(<))
#               POP_JUMP_IF_FALSE        9 (to L2)
#
#   5           LOAD_NAME                2 (print)
#               PUSH_NULL
#               LOAD_CONST               1 ('We should not take the cars.')
#               CALL                     1
#               POP_TOP
#               RETURN_CONST             3 (None)
#
#   7   L2:     LOAD_NAME                2 (print)
#               PUSH_NULL
#               LOAD_CONST               2 ("We can't decide.")
#               CALL                     1
#               POP_TOP
#               RETURN_CONST             3 (None)
